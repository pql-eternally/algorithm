# %%
from dask.distributed import Client

# %%
client = Client()
client
# Out:
# /Users/qhkjit/anaconda3/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 57667 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:57668' processes=4 threads=8, memory=16.00 GiB>
