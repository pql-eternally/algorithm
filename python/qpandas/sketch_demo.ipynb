# %%
import sketch
import pandas as pd

# %%
df = pd.read_excel('/Users/qhkjit/Desktop/钉钉任务明细数据.xlsx')
df = df[df['推送状态'] == '已推送']

# %%
df.sketch.ask("df的shape是什么样的？")
# Out:
# df的shape是(2357, 15)，其中有2357行和15列。

# %%
df.sketch.ask("这个df有哪些列？")
# Out:
# 任务ID, 主体应用, 审批单号, 表单名称, 分类, 提报人, 审批单ID, 费用单ID, 推送状态, 推送人, 推送时间, 科目ID, 科目编码, 商圈ID, 商圈名称, Code编码, Team编码, 金额

# %%
df.sketch.ask("如何筛选df推送状态是已推送，并对金额列进行求和？")
# Out:
# df[df['推送状态'] == '已推送']['金额'].sum()

# %%
df[df['推送状态'] == '已推送']['金额'].sum()
# Out:
# 584406658

# %%
df.sketch.howto("将df按用户推送的金额绘制折线图")
# Out:
# <div style="display:flex;flex-direction:row;justify-content:space-between;">
#                 <pre style="width: 100%; white-space: pre-wrap;" id="d1d8870a-5a2c-4430-b4f1-5067fa0a9961">
# import matplotlib.pyplot as plt
#
# # Get the data for the plot
# x = df['推送时间']
# y = df['金额']
#
# # Create the plot
# plt.plot(x, y)
# plt.title('推送金额折线图')
# plt.xlabel('推送时间')
# plt.ylabel('金额')
# plt.show()
# </pre>
#                 <button style="height: fit-content;" onclick="navigator.clipboard.writeText(JSON.parse(atob(`...`)))">Copy</button>
#                 </div>

# %%
import matplotlib.pyplot as plt

# Get the data for the plot
x = df['科目编码']
y = df['金额']

# Create the plot
plt.plot(x, y)
plt.title('金额折线图')
plt.xlabel('科目编码')
plt.ylabel('金额')
plt.show()
# Out:
# /Users/qhkjit/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31185 (\N{CJK UNIFIED IDEOGRAPH-79D1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/qhkjit/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/qhkjit/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32534 (\N{CJK UNIFIED IDEOGRAPH-7F16}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/qhkjit/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30721 (\N{CJK UNIFIED IDEOGRAPH-7801}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
